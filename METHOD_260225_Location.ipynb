# %% [markdown]
# ### GENERAL METHOD
# This should work without adaptations as a module

# %%
import numpy as np
from typing import List
from scipy.optimize import minimize
import matplotlib.pyplot as plt

# %%
from Point import Point
from Functions import Function, Constraint
from KM_Algo import KungMethod

# %%
#STEP 1
mu = 0.25
beta = 0.5
k = int(0)

# %% [markdown]
# ### EXAMPLE PROBLEM 1

# %%
#STEP 2
# Create 3 objects of class Point with random vectors of dimension 3


m = ["f1","f2"]

def f1(x):
    return -x[0]

def f1_d(x):
    return [-1,0]

func_f1 = Function(f1,f1_d,"f1")

def f2(x):
    return x[0] + x[1]

def f2_d(x):    
    return [1,1]

func_f2 = Function(f2,f2_d,"f2")

functions = [func_f1,func_f2]


def g1(x):
    return x[0] - 1

def g1_d(x):
    return [1,0]

constraint_g1 = Constraint(g1,g1_d,"g1")

def g2(x):
    return x[1] - 1

def g2_d(x):
    return [0,1]

constraint_g2 = Constraint(g2,g2_d,"g2")

def g3(x): 
    return -x[0]

def g3_d(x):
    return [-1,0]

constraint_g3 = Constraint(g3,g3_d,"g3")

def g4(x):
    return -x[1]

def g4_d(x):
    return [0,-1]

constraint_g4 = Constraint(g4,g4_d,"g4")

g = [constraint_g1,constraint_g2,constraint_g3,constraint_g4]
h = []

# %% [markdown]
# ### Example Problem 2
#
# MINIMISE
# $\\f_1(x) = 10x_1 + 2x_2\\$
# $f_2(x) = 3x_1 ^ 2 + 2x_2 ^ 2 + x_1$
#
# SUBJECT TO
# $\\ x_1 \geq 2\\$
# $ x_2 \geq 3 \\$
# $ x_1 + x_2 \leq 12$
#
# Both f_1 and f_2 are continously differentiable

# %%
#STEP 2
# Create 3 objects of class Point with random vectors of dimension 3


m = ["f1","f2"]

#f1
def f1(x):
    return 10*x[0] + 2*x[1]

#Partial derivatives of f1
def f1_d(x):
    return [10,2]

#Cretae object of class Function
func_f1 = Function(f1,f1_d,"f1")

def f2(x):
    return 3* x[0]**2 + 2*x[1]**2 + x[0]

def f2_d(x):
    return [6*x[0] + 1 ,4*x[1]]

func_f2 = Function(f2,f2_d,"f2")

functions = [func_f1,func_f2]


def g1(x):
    return 2 - x[0]

def g1_d(x):
    return [-1,0]

constraint_g1 = Constraint(g1,g1_d,"g1")

def g2(x):
    return 3 - x[1]

def g2_d(x):
    return [0,-1]

constraint_g2 = Constraint(g2,g2_d,"g2")

def g3(x): 
    return x[1] + x[0] - 12

def g3_d(x):
    return [1,1]

constraint_g3 = Constraint(g3,g3_d,"g3")

g = [constraint_g1,constraint_g2,constraint_g3]
h = []

# %% [markdown]
# ### Example Problem 3
#
# MINIMISE
# $\\f_1(x) = (x_1 - 2)^2 + (x_2 -3)^2\\$
# $f_2(x) = (\frac{x_1}{2})^2 +(\frac{x_2}{5})^2 + 10 sin(x_1)cos(x_2) $
#
# SUBJECT TO
# $\\1 \le x_1 \le 5\\$
# $0 \le x_" \le 6\\$
#
# Both f_1 and f_2 are continously differentiable

# %%
#STEP 2
# Create 3 objects of class Point with random vectors of dimension 3


from math import cos, sin


m = ["f1","f2"]

#f1
def f1(x):
    return (x[0] - 2)**2 + (x[1] - 3)**2

#Partial derivatives of f1
def f1_d(x):
    return [2*(x[0] - 2),2*(x[1] - 3)]

#Cretae object of class Function
func_f1 = Function(f1,f1_d,"f1")

def f2(x):
    return (x[0]/2)**2 + (x[1]/5)**2 + 10 * sin(x[0])*cos(x[1]) 

def f2_d(x):
    t1 = x[0]/2 + 10*cos(x[0])*cos(x[1])
    t2 = (2 *x[1])/25 - 10*sin(x[0])*sin(x[1])
    return [t1,t2]

func_f2 = Function(f2,f2_d,"f2")

functions = [func_f1,func_f2]


def g1(x):
    return 1 - x[0]

def g1_d(x):
    return [-1,0]

constraint_g1 = Constraint(g1,g1_d,"g1")

def g2(x):
    return x[0] - 5

def g2_d(x):
    return [1,0]

constraint_g2 = Constraint(g2,g2_d,"g2")

def g3(x): 
    return -x[1]

def g3_d(x):
    return [0,-1]

constraint_g3 = Constraint(g3,g3_d,"g3")

def g4(x): 
    return x[1] - 6

def g4_d(x):
    return [0,1]

constraint_g3 = Constraint(g3,g3_d,"g4")

g = [constraint_g1,constraint_g2,constraint_g3,constraint_g4]
h = []

# %%
#Generate points
np.random.seed(41)

n=1000
Xorg = []

for i in range(n):
    point = Point (np.random.rand(2))  
    point.evaluate(functions)
    Xorg.append(point)

# %%
X0 = Xorg.copy()
print(type(X0))
f_val = []

i = 1

# # fig, ax = plt.subplots()
# # for point in X0:
# #     plt.scatter(point.vector[0], point.vector[1], color='blue')
# #     ax.annotate('x'+str(i), (point.vector[0], point.vector[1]))
# #     i += 1
# #     f_val.append(point.eval_f)

 

# # plt.xlabel('X1')
# plt.ylabel('X2')
# plt.title('Initial Points Visualization')
# plt.legend()
# plt.show()

# for val in f_val:
#     plt.scatter(val[0], val[1], color='red')

# plt.xlabel('f1')
# plt.ylabel('f2')
# plt.title('Function Values Visualization')
# plt.show()

V = KungMethod(X0)

fig, ax = plt.subplots()

f_val = []
for point in V:
    plt.scatter(point.vector[0], point.vector[1], color='blue')
    ax.annotate('x'+str(i), (point.vector[0], point.vector[1]))
    f_val.append(point.eval_f)
 

plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Initial Points Visualization')
plt.legend()
plt.show()

for val in f_val:
    plt.scatter(val[0], val[1], color='red')

plt.xlabel('f1')
plt.ylabel('f2')
plt.title('Function Values Visualization')
plt.show()
# Out:
# <class 'list'>
# C:\Users\ellie\AppData\Local\Temp\ipykernel_6784\201232420.py:44: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
def search_dir(x,g:List[Constraint],h:List[Constraint],f1:Function,n:int):
    """
    Solve the quadratic optimisation problem
    min delta(f)^T * d + 1/2 * d^T * H * d

    Args: x - current point
          g - list of functions that define inequality <= constraints
          h - list of functions that define equality == constraints
          f1_d - gradient of the function f1 at x
          

    Returns: d
    Note: H is currently the Identity matrix
    
    """

    x_v = x.vector
    df_x = x.eval_d[n]
    # Define the objective function for scipy minimize
    def objective(d):
        return np.dot(df_x, d) + 0.5 * np.dot(d, d)

    # Define the constraints for scipy minimize
    constraints = []
    for f in g:
        constraints.append({'type': 'ineq', 'fun': lambda d, f=f: f(x_v) + np.dot(f.evaluate_gradient(x_v), d)})

    for f in h:
        constraints.append({'type': 'eq', 'fun': lambda d, f=f: f(x_v) + np.dot(f.evaluate_gradient(x_v), d)})

    # Initial guess for d
    d0 = np.zeros(len(x_v))

    # Solve the optimization problem
    result = minimize(objective, d0, constraints=constraints)

    d_values = result.x

    return d_values

# %%
#CALCULATING PENALTY PARAMETER

def penalty(g: List[Constraint], h: List[Constraint], x: Point,f1:Function,beta, b: float = 0.001):
      """
      Calculate the penalty parameter for a given point x
      as described in:
      A SUPERLINEARLY CONVERGENT ALGORITHM FOR CONSTRAINED OPTIMIZATION PROBLEMS*

      Args: g - list of functions that define inequality <= constraints
            h - list of functions that define equality == constraints
            x - current point
            mu - penalty parameter

      Returns: mu
      """

      x_vector = x.vector

      
      #TODO maybe calc this as input to avoid repeated calculations
      #Matrix of deriv calculations
      G_d = [g[i].evaluate_gradient(x_vector) for i in range(len(g))]
      H_d = [h[i].evaluate_gradient(x) for i in range(len(h))] 

      #TODO move next calc out of function and pass as input , place before main loop in order to avoid repeated calculations
      #Max value of g and h func evaled at x
      G = [g[i](x_vector) for i in range(len(g))]
      H = [np.abs(h[i].func(x_vector)) for i in range(len(h))]
      psi = max(max(G, default=float('-inf')), max(H, default=float('-inf')))


      def minFunc(l_mu):
            l = l_mu[:len(G)]
            mu = l_mu[len(G):]
            term1 = np.linalg.norm(f1.evaluate_gradient(x_vector) + np.dot(np.array(G_d).T,l) + np.dot(np.array(H_d).T,mu))**2
            term2 = np.sum([((psi -G[i])**2)*(l[i]**2) for i in range(len(G))])
            term3 = np.sum([((psi -np.abs(H[i]))**2)*(mu[i]**2) for i in range(len(H))])
            return term1 + term2 + term3 
      
      initial_guess = np.zeros(len(G) + len(H))
      result = minimize(minFunc, initial_guess)
      
      l_opt = result.x[:len(G)]
      mu_opt = result.x[len(G):]
      #Calculate the penalty parameter
      
      c = np.sum(l_opt) + sum(np.linalg.norm(vector) for vector in mu_opt)
      c = max(c + b, b)

      #Penalty func = f(x) + c * psi(x)
      f1_x = f1(x_vector)
    
      return c,psi

# %%
#merit function
def merit(x,g:List[Constraint],h:List[Constraint],f1:Function, p):
      """
      Calculate the merit function for a given point x
      as described in:
      A SUPERLINEARLY CONVERGENT ALGORITHM FOR CONSTRAINED OPTIMIZATION PROBLEMS*

      Args: x - current point
            g - list of functions that define inequality <= constraints
            h - list of functions that define equality == constraints
            f1 - function to be minimised
            mu - penalty parameter

            

      Returns: merit function value
      """

      m = f1(x) + p* (sum([g[i].func(x) for i in range(len(g))])) + p * (sum([np.abs(h[i].func(x)) for i in range(len(h))]))
      return m

# %%
#merit function
def merit_d(x: List,g:List[Constraint],h:List[Constraint],f1:Function, psi,d):
      """
      Calculate the merit function for a given point x
      as described in:
      A SUPERLINEARLY CONVERGENT ALGORITHM FOR CONSTRAINED OPTIMIZATION PROBLEMS*

      Args: x - current point
            g - list of functions that define inequality <= constraints
            h - list of functions that define equality == constraints
            f1 - function to be minimised
            mu - penalty parameter

      Returns: merit function value
      """

      G_deriv = [g[i].evaluate_gradient(x) * d for i in range(len(g))]
      H_deriv = [h[i].evaluate_gradient(x) * d if h[i](x) == 0 else 0 for i in range(len(h))]


      dir_deriv = G_deriv + H_deriv
      

      m_d = np.dot(f1.evaluate_gradient(x),d)
      m_d = m_d + psi * (np.linalg.norm(dir_deriv))

      return m_d

# %%
def alpha_val(x:Point, d, beta,c,psi, g:List[Constraint], h:List[Constraint], f1:Function, mu):
    """
    Calculate the step size for a given point x
    as described in:
    A SUPERLINEARLY CONVERGENT ALGORITHM FOR CONSTRAINED OPTIMIZATION PROBLEMS*

    Args: x - current point
          beta - step size reduction factor
          g - list of functions that define inequality <= constraints
          h - list of functions that define equality == constraints
          f1 - function to be minimised

    Returns: alpha
    """
    x_vector = x.vector
    #Calculate the step size
    pen1 = f1(x_vector) 
    pen = pen1  + c * psi
    alpha = 1
    while True:
        #TODO : the output dimensions do not match
        merit1 = merit(x_vector + alpha*d,g,h,f1,pen)
        merit2 = merit(x_vector,g,h,f1,pen) + mu * alpha * merit_d(x_vector,g,h,f1,psi,d)

        if merit1 <= merit2:
            break
        alpha = alpha * beta

    return alpha

# %%
def display(X:List[Point],XS:List[Point]):
    import matplotlib.pyplot as plt

    
    for point in XS:
        plt.scatter(point.eval_f[0], point.eval_f[1], color='red', label='XS' if 'XS' not in plt.gca().get_legend_handles_labels()[1] else "")

    for point in X:
        plt.scatter(point.eval_f[0], point.eval_f[1], color='blue', label='X0' if 'X0' not in plt.gca().get_legend_handles_labels()[1] else "")

    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title('Function Visualization')
    plt.legend()
    plt.show()


    for point in XS:
        plt.scatter(point.vector[0], point.vector[1], color='red', label='XS' if 'XS' not in plt.gca().get_legend_handles_labels()[1] else "")

    for point in X:
        plt.scatter(point.vector[0], point.vector[1], color='blue', label='X0' if 'X0' not in plt.gca().get_legend_handles_labels()[1] else "")

    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.title('Points Visualization')
    plt.legend()
    plt.show()

# %%
#Number of iterations
from numpy import concat, concatenate

X0 = Xorg.copy()


iter = 1000
#Tolerance
tol = 0.0001

#Num of objectives



#SET OF "STOPPED" POINTS
#HOW MANY ITERATIONS TO RUN BEFORE STOPPING
for i in range(iter):
    T = []
    #FOR EACH POINT IN X0 THE SET OF RANDOM POINTS
    for p in X0:

        #CHEK IF POINT IS STOPPED
        if p.stopped != True:

            #FOR EACH OBJECTIVE FUNCTION
            for j in range(0,len(functions)):
                
                #COMPUTE SEARCH DIRECTION
                #TODO:CHange this to include constraints as well
                d = search_dir(p,g,h,functions[j],j)

                #IF SEARCH DIRECTION IS TOO SMALL,CONTINUE TO EVAL NEXT OBJ FUNC
                if np.linalg.norm(d) < np.power(tol, 1/4):
                    continue

                c,psi = penalty(g,h,p,functions[j],mu)

                alpha = alpha_val(p, np.array(d), beta, c, psi, g, h, functions[j], mu)

                if np.linalg.norm(d) < np.sqrt(tol):
                    continue

                p_new = Point(p.vector + alpha * np.array(d))
                p_new.evaluate(functions)

                T.append(p_new)

            p.stopped = True
    
    X0.extend(T)
    print(f"Iter {i}, X length {len(X0)}")
    X0 = KungMethod(X0)
# Out:
# Iter 0, X length 1000
# Iter 1, X length 45
# Iter 2, X length 45
# Iter 3, X length 45
# Iter 4, X length 45
# Iter 5, X length 45
# Iter 6, X length 45
# Iter 7, X length 45
# Iter 8, X length 45
# Iter 9, X length 45
# Iter 10, X length 45
# Iter 11, X length 45
# Iter 12, X length 45
# Iter 13, X length 45
# Iter 14, X length 45
# Iter 15, X length 45
# Iter 16, X length 45
# Iter 17, X length 45
# Iter 18, X length 45
# Iter 19, X length 45
# Iter 20, X length 45
# Iter 21, X length 45
# Iter 22, X length 45
# Iter 23, X length 45
# Iter 24, X length 45
# Iter 25, X length 45
# Iter 26, X length 45
# Iter 27, X length 45
# Iter 28, X length 45
# Iter 29, X length 45
# Iter 30, X length 45
# Iter 31, X length 45
# Iter 32, X length 45
# Iter 33, X length 45
# Iter 34, X length 45
# Iter 35, X length 45
# Iter 36, X length 45
# Iter 37, X length 45
# Iter 38, X length 45
# Iter 39, X length 45
# Iter 40, X length 45
# Iter 41, X length 45
# Iter 42, X length 45
# Iter 43, X length 45
# Iter 44, X length 45
# Iter 45, X length 45
# Iter 46, X length 45
# Iter 47, X length 45
# Iter 48, X length 45
# Iter 49, X length 45
# Iter 50, X length 45
# Iter 51, X length 45
# Iter 52, X length 45
# Iter 53, X length 45
# Iter 54, X length 45
# Iter 55, X length 45
# Iter 56, X length 45
# Iter 57, X length 45
# Iter 58, X length 45
# Iter 59, X length 45
# Iter 60, X length 45
# Iter 61, X length 45
# Iter 62, X length 45
# Iter 63, X length 45
# Iter 64, X length 45
# Iter 65, X length 45
# Iter 66, X length 45
# Iter 67, X length 45
# Iter 68, X length 45
# Iter 69, X length 45
# Iter 70, X length 45
# Iter 71, X length 45
# Iter 72, X length 45
# Iter 73, X length 45
# Iter 74, X length 45
# Iter 75, X length 45
# Iter 76, X length 45
# Iter 77, X length 45
# Iter 78, X length 45
# Iter 79, X length 45
# Iter 80, X length 45
# Iter 81, X length 45
# Iter 82, X length 45
# Iter 83, X length 45
# Iter 84, X length 45
# Iter 85, X length 45
# Iter 86, X length 45
# Iter 87, X length 45
# Iter 88, X length 45
# Iter 89, X length 45
# Iter 90, X length 45
# Iter 91, X length 45
# Iter 92, X length 45
# Iter 93, X length 45
# Iter 94, X length 45
# Iter 95, X length 45
# Iter 96, X length 45
# Iter 97, X length 45
# Iter 98, X length 45
# Iter 99, X length 45
# Iter 100, X length 45
# Iter 101, X length 45
# Iter 102, X length 45
# Iter 103, X length 45
# Iter 104, X length 45
# Iter 105, X length 45
# Iter 106, X length 45
# Iter 107, X length 45
# Iter 108, X length 45
# Iter 109, X length 45
# Iter 110, X length 45
# Iter 111, X length 45
# Iter 112, X length 45
# Iter 113, X length 45
# Iter 114, X length 45
# Iter 115, X length 45
# Iter 116, X length 45
# Iter 117, X length 45
# Iter 118, X length 45
# Iter 119, X length 45
# Iter 120, X length 45
# Iter 121, X length 45
# Iter 122, X length 45
# Iter 123, X length 45
# Iter 124, X length 45
# Iter 125, X length 45
# Iter 126, X length 45
# Iter 127, X length 45
# Iter 128, X length 45
# Iter 129, X length 45
# Iter 130, X length 45
# Iter 131, X length 45
# Iter 132, X length 45
# Iter 133, X length 45
# Iter 134, X length 45
# Iter 135, X length 45
# Iter 136, X length 45
# Iter 137, X length 45
# Iter 138, X length 45
# Iter 139, X length 45
# Iter 140, X length 45
# Iter 141, X length 45
# Iter 142, X length 45
# Iter 143, X length 45
# Iter 144, X length 45
# Iter 145, X length 45
# Iter 146, X length 45
# Iter 147, X length 45
# Iter 148, X length 45
# Iter 149, X length 45
# Iter 150, X length 45
# Iter 151, X length 45
# Iter 152, X length 45
# Iter 153, X length 45
# Iter 154, X length 45
# Iter 155, X length 45
# Iter 156, X length 45
# Iter 157, X length 45
# Iter 158, X length 45
# Iter 159, X length 45
# Iter 160, X length 45
# Iter 161, X length 45
# Iter 162, X length 45
# Iter 163, X length 45
# Iter 164, X length 45
# Iter 165, X length 45
# Iter 166, X length 45
# Iter 167, X length 45
# Iter 168, X length 45
# Iter 169, X length 45
# Iter 170, X length 45
# Iter 171, X length 45
# Iter 172, X length 45
# Iter 173, X length 45
# Iter 174, X length 45
# Iter 175, X length 45
# Iter 176, X length 45
# Iter 177, X length 45
# Iter 178, X length 45
# Iter 179, X length 45
# Iter 180, X length 45
# Iter 181, X length 45
# Iter 182, X length 45
# Iter 183, X length 45
# Iter 184, X length 45
# Iter 185, X length 45
# Iter 186, X length 45
# Iter 187, X length 45
# Iter 188, X length 45
# Iter 189, X length 45
# Iter 190, X length 45
# Iter 191, X length 45
# Iter 192, X length 45
# Iter 193, X length 45
# Iter 194, X length 45
# Iter 195, X length 45
# Iter 196, X length 45
# Iter 197, X length 45
# Iter 198, X length 45
# Iter 199, X length 45
# Iter 200, X length 45
# Iter 201, X length 45
# Iter 202, X length 45
# Iter 203, X length 45
# Iter 204, X length 45
# Iter 205, X length 45
# Iter 206, X length 45
# Iter 207, X length 45
# Iter 208, X length 45
# Iter 209, X length 45
# Iter 210, X length 45
# Iter 211, X length 45
# Iter 212, X length 45
# Iter 213, X length 45
# Iter 214, X length 45
# Iter 215, X length 45
# Iter 216, X length 45
# Iter 217, X length 45
# Iter 218, X length 45
# Iter 219, X length 45
# Iter 220, X length 45
# Iter 221, X length 45
# Iter 222, X length 45
# Iter 223, X length 45
# Iter 224, X length 45
# Iter 225, X length 45
# Iter 226, X length 45
# Iter 227, X length 45
# Iter 228, X length 45
# Iter 229, X length 45
# Iter 230, X length 45
# Iter 231, X length 45
# Iter 232, X length 45
# Iter 233, X length 45
# Iter 234, X length 45
# Iter 235, X length 45
# Iter 236, X length 45
# Iter 237, X length 45
# Iter 238, X length 45
# Iter 239, X length 45
# Iter 240, X length 45
# Iter 241, X length 45
# Iter 242, X length 45
# Iter 243, X length 45
# Iter 244, X length 45
# Iter 245, X length 45
# Iter 246, X length 45
# Iter 247, X length 45
# Iter 248, X length 45
# Iter 249, X length 45
# Iter 250, X length 45
# Iter 251, X length 45
# Iter 252, X length 45
# Iter 253, X length 45
# Iter 254, X length 45
# Iter 255, X length 45
# Iter 256, X length 45
# Iter 257, X length 45
# Iter 258, X length 45
# Iter 259, X length 45
# Iter 260, X length 45
# Iter 261, X length 45
# Iter 262, X length 45
# Iter 263, X length 45
# Iter 264, X length 45
# Iter 265, X length 45
# Iter 266, X length 45
# Iter 267, X length 45
# Iter 268, X length 45
# Iter 269, X length 45
# Iter 270, X length 45
# Iter 271, X length 45
# Iter 272, X length 45
# Iter 273, X length 45
# Iter 274, X length 45
# Iter 275, X length 45
# Iter 276, X length 45
# Iter 277, X length 45
# Iter 278, X length 45
# Iter 279, X length 45
# Iter 280, X length 45
# Iter 281, X length 45
# Iter 282, X length 45
# Iter 283, X length 45
# Iter 284, X length 45
# Iter 285, X length 45
# Iter 286, X length 45
# Iter 287, X length 45
# Iter 288, X length 45
# Iter 289, X length 45
# Iter 290, X length 45
# Iter 291, X length 45
# Iter 292, X length 45
# Iter 293, X length 45
# Iter 294, X length 45
# Iter 295, X length 45
# Iter 296, X length 45
# Iter 297, X length 45
# Iter 298, X length 45
# Iter 299, X length 45
# Iter 300, X length 45
# Iter 301, X length 45
# Iter 302, X length 45
# Iter 303, X length 45
# Iter 304, X length 45
# Iter 305, X length 45
# Iter 306, X length 45
# Iter 307, X length 45
# Iter 308, X length 45
# Iter 309, X length 45
# Iter 310, X length 45
# Iter 311, X length 45
# Iter 312, X length 45
# Iter 313, X length 45
# Iter 314, X length 45
# Iter 315, X length 45
# Iter 316, X length 45
# Iter 317, X length 45
# Iter 318, X length 45
# Iter 319, X length 45
# Iter 320, X length 45
# Iter 321, X length 45
# Iter 322, X length 45
# Iter 323, X length 45
# Iter 324, X length 45
# Iter 325, X length 45
# Iter 326, X length 45
# Iter 327, X length 45
# Iter 328, X length 45
# Iter 329, X length 45
# Iter 330, X length 45
# Iter 331, X length 45
# Iter 332, X length 45
# Iter 333, X length 45
# Iter 334, X length 45
# Iter 335, X length 45
# Iter 336, X length 45
# Iter 337, X length 45
# Iter 338, X length 45
# Iter 339, X length 45
# Iter 340, X length 45
# Iter 341, X length 45
# Iter 342, X length 45
# Iter 343, X length 45
# Iter 344, X length 45
# Iter 345, X length 45
# Iter 346, X length 45
# Iter 347, X length 45
# Iter 348, X length 45
# Iter 349, X length 45
# Iter 350, X length 45
# Iter 351, X length 45
# Iter 352, X length 45
# Iter 353, X length 45
# Iter 354, X length 45
# Iter 355, X length 45
# Iter 356, X length 45
# Iter 357, X length 45
# Iter 358, X length 45
# Iter 359, X length 45
# Iter 360, X length 45
# Iter 361, X length 45
# Iter 362, X length 45
# Iter 363, X length 45
# Iter 364, X length 45
# Iter 365, X length 45
# Iter 366, X length 45
# Iter 367, X length 45
# Iter 368, X length 45
# Iter 369, X length 45
# Iter 370, X length 45
# Iter 371, X length 45
# Iter 372, X length 45
# Iter 373, X length 45
# Iter 374, X length 45
# Iter 375, X length 45
# Iter 376, X length 45
# Iter 377, X length 45
# Iter 378, X length 45
# Iter 379, X length 45
# Iter 380, X length 45
# Iter 381, X length 45
# Iter 382, X length 45
# Iter 383, X length 45
# Iter 384, X length 45
# Iter 385, X length 45
# Iter 386, X length 45
# Iter 387, X length 45
# Iter 388, X length 45
# Iter 389, X length 45
# Iter 390, X length 45
# Iter 391, X length 45
# Iter 392, X length 45
# Iter 393, X length 45
# Iter 394, X length 45
# Iter 395, X length 45
# Iter 396, X length 45
# Iter 397, X length 45
# Iter 398, X length 45
# Iter 399, X length 45
# Iter 400, X length 45
# Iter 401, X length 45
# Iter 402, X length 45
# Iter 403, X length 45
# Iter 404, X length 45
# Iter 405, X length 45
# Iter 406, X length 45
# Iter 407, X length 45
# Iter 408, X length 45
# Iter 409, X length 45
# Iter 410, X length 45
# Iter 411, X length 45
# Iter 412, X length 45
# Iter 413, X length 45
# Iter 414, X length 45
# Iter 415, X length 45
# Iter 416, X length 45
# Iter 417, X length 45
# Iter 418, X length 45
# Iter 419, X length 45
# Iter 420, X length 45
# Iter 421, X length 45
# Iter 422, X length 45
# Iter 423, X length 45
# Iter 424, X length 45
# Iter 425, X length 45
# Iter 426, X length 45
# Iter 427, X length 45
# Iter 428, X length 45
# Iter 429, X length 45
# Iter 430, X length 45
# Iter 431, X length 45
# Iter 432, X length 45
# Iter 433, X length 45
# Iter 434, X length 45
# Iter 435, X length 45
# Iter 436, X length 45
# Iter 437, X length 45
# Iter 438, X length 45
# Iter 439, X length 45
# Iter 440, X length 45
# Iter 441, X length 45
# Iter 442, X length 45
# Iter 443, X length 45
# Iter 444, X length 45
# Iter 445, X length 45
# Iter 446, X length 45
# Iter 447, X length 45
# Iter 448, X length 45
# Iter 449, X length 45
# Iter 450, X length 45
# Iter 451, X length 45
# Iter 452, X length 45
# Iter 453, X length 45
# Iter 454, X length 45
# Iter 455, X length 45
# Iter 456, X length 45
# Iter 457, X length 45
# Iter 458, X length 45
# Iter 459, X length 45
# Iter 460, X length 45
# Iter 461, X length 45
# Iter 462, X length 45
# Iter 463, X length 45
# Iter 464, X length 45
# Iter 465, X length 45
# Iter 466, X length 45
# Iter 467, X length 45
# Iter 468, X length 45
# Iter 469, X length 45
# Iter 470, X length 45
# Iter 471, X length 45
# Iter 472, X length 45
# Iter 473, X length 45
# Iter 474, X length 45
# Iter 475, X length 45
# Iter 476, X length 45
# Iter 477, X length 45
# Iter 478, X length 45
# Iter 479, X length 45
# Iter 480, X length 45
# Iter 481, X length 45
# Iter 482, X length 45
# Iter 483, X length 45
# Iter 484, X length 45
# Iter 485, X length 45
# Iter 486, X length 45
# Iter 487, X length 45
# Iter 488, X length 45
# Iter 489, X length 45
# Iter 490, X length 45
# Iter 491, X length 45
# Iter 492, X length 45
# Iter 493, X length 45
# Iter 494, X length 45
# Iter 495, X length 45
# Iter 496, X length 45
# Iter 497, X length 45
# Iter 498, X length 45
# Iter 499, X length 45
# Iter 500, X length 45
# Iter 501, X length 45
# Iter 502, X length 45
# Iter 503, X length 45
# Iter 504, X length 45
# Iter 505, X length 45
# Iter 506, X length 45
# Iter 507, X length 45
# Iter 508, X length 45
# Iter 509, X length 45
# Iter 510, X length 45
# Iter 511, X length 45
# Iter 512, X length 45
# Iter 513, X length 45
# Iter 514, X length 45
# Iter 515, X length 45
# Iter 516, X length 45
# Iter 517, X length 45
# Iter 518, X length 45
# Iter 519, X length 45
# Iter 520, X length 45
# Iter 521, X length 45
# Iter 522, X length 45
# Iter 523, X length 45
# Iter 524, X length 45
# Iter 525, X length 45
# Iter 526, X length 45
# Iter 527, X length 45
# Iter 528, X length 45
# Iter 529, X length 45
# Iter 530, X length 45
# Iter 531, X length 45
# Iter 532, X length 45
# Iter 533, X length 45
# Iter 534, X length 45
# Iter 535, X length 45
# Iter 536, X length 45
# Iter 537, X length 45
# Iter 538, X length 45
# Iter 539, X length 45
# Iter 540, X length 45
# Iter 541, X length 45
# Iter 542, X length 45
# Iter 543, X length 45
# Iter 544, X length 45
# Iter 545, X length 45
# Iter 546, X length 45
# Iter 547, X length 45
# Iter 548, X length 45
# Iter 549, X length 45
# Iter 550, X length 45
# Iter 551, X length 45
# Iter 552, X length 45
# Iter 553, X length 45
# Iter 554, X length 45
# Iter 555, X length 45
# Iter 556, X length 45
# Iter 557, X length 45
# Iter 558, X length 45
# Iter 559, X length 45
# Iter 560, X length 45
# Iter 561, X length 45
# Iter 562, X length 45
# Iter 563, X length 45
# Iter 564, X length 45
# Iter 565, X length 45
# Iter 566, X length 45
# Iter 567, X length 45
# Iter 568, X length 45
# Iter 569, X length 45
# Iter 570, X length 45
# Iter 571, X length 45
# Iter 572, X length 45
# Iter 573, X length 45
# Iter 574, X length 45
# Iter 575, X length 45
# Iter 576, X length 45
# Iter 577, X length 45
# Iter 578, X length 45
# Iter 579, X length 45
# Iter 580, X length 45
# Iter 581, X length 45
# Iter 582, X length 45
# Iter 583, X length 45
# Iter 584, X length 45
# Iter 585, X length 45
# Iter 586, X length 45
# Iter 587, X length 45
# Iter 588, X length 45
# Iter 589, X length 45
# Iter 590, X length 45
# Iter 591, X length 45
# Iter 592, X length 45
# Iter 593, X length 45
# Iter 594, X length 45
# Iter 595, X length 45
# Iter 596, X length 45
# Iter 597, X length 45
# Iter 598, X length 45
# Iter 599, X length 45
# Iter 600, X length 45
# Iter 601, X length 45
# Iter 602, X length 45
# Iter 603, X length 45
# Iter 604, X length 45
# Iter 605, X length 45
# Iter 606, X length 45
# Iter 607, X length 45
# Iter 608, X length 45
# Iter 609, X length 45
# Iter 610, X length 45
# Iter 611, X length 45
# Iter 612, X length 45
# Iter 613, X length 45
# Iter 614, X length 45
# Iter 615, X length 45
# Iter 616, X length 45
# Iter 617, X length 45
# Iter 618, X length 45
# Iter 619, X length 45
# Iter 620, X length 45
# Iter 621, X length 45
# Iter 622, X length 45
# Iter 623, X length 45
# Iter 624, X length 45
# Iter 625, X length 45
# Iter 626, X length 45
# Iter 627, X length 45
# Iter 628, X length 45
# Iter 629, X length 45
# Iter 630, X length 45
# Iter 631, X length 45
# Iter 632, X length 45
# Iter 633, X length 45
# Iter 634, X length 45
# Iter 635, X length 45
# Iter 636, X length 45
# Iter 637, X length 45
# Iter 638, X length 45
# Iter 639, X length 45
# Iter 640, X length 45
# Iter 641, X length 45
# Iter 642, X length 45
# Iter 643, X length 45
# Iter 644, X length 45
# Iter 645, X length 45
# Iter 646, X length 45
# Iter 647, X length 45
# Iter 648, X length 45
# Iter 649, X length 45
# Iter 650, X length 45
# Iter 651, X length 45
# Iter 652, X length 45
# Iter 653, X length 45
# Iter 654, X length 45
# Iter 655, X length 45
# Iter 656, X length 45
# Iter 657, X length 45
# Iter 658, X length 45
# Iter 659, X length 45
# Iter 660, X length 45
# Iter 661, X length 45
# Iter 662, X length 45
# Iter 663, X length 45
# Iter 664, X length 45
# Iter 665, X length 45
# Iter 666, X length 45
# Iter 667, X length 45
# Iter 668, X length 45
# Iter 669, X length 45
# Iter 670, X length 45
# Iter 671, X length 45
# Iter 672, X length 45
# Iter 673, X length 45
# Iter 674, X length 45
# Iter 675, X length 45
# Iter 676, X length 45
# Iter 677, X length 45
# Iter 678, X length 45
# Iter 679, X length 45
# Iter 680, X length 45
# Iter 681, X length 45
# Iter 682, X length 45
# Iter 683, X length 45
# Iter 684, X length 45
# Iter 685, X length 45
# Iter 686, X length 45
# Iter 687, X length 45
# Iter 688, X length 45
# Iter 689, X length 45
# Iter 690, X length 45
# Iter 691, X length 45
# Iter 692, X length 45
# Iter 693, X length 45
# Iter 694, X length 45
# Iter 695, X length 45
# Iter 696, X length 45
# Iter 697, X length 45
# Iter 698, X length 45
# Iter 699, X length 45
# Iter 700, X length 45
# Iter 701, X length 45
# Iter 702, X length 45
# Iter 703, X length 45
# Iter 704, X length 45
# Iter 705, X length 45
# Iter 706, X length 45
# Iter 707, X length 45
# Iter 708, X length 45
# Iter 709, X length 45
# Iter 710, X length 45
# Iter 711, X length 45
# Iter 712, X length 45
# Iter 713, X length 45
# Iter 714, X length 45
# Iter 715, X length 45
# Iter 716, X length 45
# Iter 717, X length 45
# Iter 718, X length 45
# Iter 719, X length 45
# Iter 720, X length 45
# Iter 721, X length 45
# Iter 722, X length 45
# Iter 723, X length 45
# Iter 724, X length 45
# Iter 725, X length 45
# Iter 726, X length 45
# Iter 727, X length 45
# Iter 728, X length 45
# Iter 729, X length 45
# Iter 730, X length 45
# Iter 731, X length 45
# Iter 732, X length 45
# Iter 733, X length 45
# Iter 734, X length 45
# Iter 735, X length 45
# Iter 736, X length 45
# Iter 737, X length 45
# Iter 738, X length 45
# Iter 739, X length 45
# Iter 740, X length 45
# Iter 741, X length 45
# Iter 742, X length 45
# Iter 743, X length 45
# Iter 744, X length 45
# Iter 745, X length 45
# Iter 746, X length 45
# Iter 747, X length 45
# Iter 748, X length 45
# Iter 749, X length 45
# Iter 750, X length 45
# Iter 751, X length 45
# Iter 752, X length 45
# Iter 753, X length 45
# Iter 754, X length 45
# Iter 755, X length 45
# Iter 756, X length 45
# Iter 757, X length 45
# Iter 758, X length 45
# Iter 759, X length 45
# Iter 760, X length 45
# Iter 761, X length 45
# Iter 762, X length 45
# Iter 763, X length 45
# Iter 764, X length 45
# Iter 765, X length 45
# Iter 766, X length 45
# Iter 767, X length 45
# Iter 768, X length 45
# Iter 769, X length 45
# Iter 770, X length 45
# Iter 771, X length 45
# Iter 772, X length 45
# Iter 773, X length 45
# Iter 774, X length 45
# Iter 775, X length 45
# Iter 776, X length 45
# Iter 777, X length 45
# Iter 778, X length 45
# Iter 779, X length 45
# Iter 780, X length 45
# Iter 781, X length 45
# Iter 782, X length 45
# Iter 783, X length 45
# Iter 784, X length 45
# Iter 785, X length 45
# Iter 786, X length 45
# Iter 787, X length 45
# Iter 788, X length 45
# Iter 789, X length 45
# Iter 790, X length 45
# Iter 791, X length 45
# Iter 792, X length 45
# Iter 793, X length 45
# Iter 794, X length 45
# Iter 795, X length 45
# Iter 796, X length 45
# Iter 797, X length 45
# Iter 798, X length 45
# Iter 799, X length 45
# Iter 800, X length 45
# Iter 801, X length 45
# Iter 802, X length 45
# Iter 803, X length 45
# Iter 804, X length 45
# Iter 805, X length 45
# Iter 806, X length 45
# Iter 807, X length 45
# Iter 808, X length 45
# Iter 809, X length 45
# Iter 810, X length 45
# Iter 811, X length 45
# Iter 812, X length 45
# Iter 813, X length 45
# Iter 814, X length 45
# Iter 815, X length 45
# Iter 816, X length 45
# Iter 817, X length 45
# Iter 818, X length 45
# Iter 819, X length 45
# Iter 820, X length 45
# Iter 821, X length 45
# Iter 822, X length 45
# Iter 823, X length 45
# Iter 824, X length 45
# Iter 825, X length 45
# Iter 826, X length 45
# Iter 827, X length 45
# Iter 828, X length 45
# Iter 829, X length 45
# Iter 830, X length 45
# Iter 831, X length 45
# Iter 832, X length 45
# Iter 833, X length 45
# Iter 834, X length 45
# Iter 835, X length 45
# Iter 836, X length 45
# Iter 837, X length 45
# Iter 838, X length 45
# Iter 839, X length 45
# Iter 840, X length 45
# Iter 841, X length 45
# Iter 842, X length 45
# Iter 843, X length 45
# Iter 844, X length 45
# Iter 845, X length 45
# Iter 846, X length 45
# Iter 847, X length 45
# Iter 848, X length 45
# Iter 849, X length 45
# Iter 850, X length 45
# Iter 851, X length 45
# Iter 852, X length 45
# Iter 853, X length 45
# Iter 854, X length 45
# Iter 855, X length 45
# Iter 856, X length 45
# Iter 857, X length 45
# Iter 858, X length 45
# Iter 859, X length 45
# Iter 860, X length 45
# Iter 861, X length 45
# Iter 862, X length 45
# Iter 863, X length 45
# Iter 864, X length 45
# Iter 865, X length 45
# Iter 866, X length 45
# Iter 867, X length 45
# Iter 868, X length 45
# Iter 869, X length 45
# Iter 870, X length 45
# Iter 871, X length 45
# Iter 872, X length 45
# Iter 873, X length 45
# Iter 874, X length 45
# Iter 875, X length 45
# Iter 876, X length 45
# Iter 877, X length 45
# Iter 878, X length 45
# Iter 879, X length 45
# Iter 880, X length 45
# Iter 881, X length 45
# Iter 882, X length 45
# Iter 883, X length 45
# Iter 884, X length 45
# Iter 885, X length 45
# Iter 886, X length 45
# Iter 887, X length 45
# Iter 888, X length 45
# Iter 889, X length 45
# Iter 890, X length 45
# Iter 891, X length 45
# Iter 892, X length 45
# Iter 893, X length 45
# Iter 894, X length 45
# Iter 895, X length 45
# Iter 896, X length 45
# Iter 897, X length 45
# Iter 898, X length 45
# Iter 899, X length 45
# Iter 900, X length 45
# Iter 901, X length 45
# Iter 902, X length 45
# Iter 903, X length 45
# Iter 904, X length 45
# Iter 905, X length 45
# Iter 906, X length 45
# Iter 907, X length 45
# Iter 908, X length 45
# Iter 909, X length 45
# Iter 910, X length 45
# Iter 911, X length 45
# Iter 912, X length 45
# Iter 913, X length 45
# Iter 914, X length 45
# Iter 915, X length 45
# Iter 916, X length 45
# Iter 917, X length 45
# Iter 918, X length 45
# Iter 919, X length 45
# Iter 920, X length 45
# Iter 921, X length 45
# Iter 922, X length 45
# Iter 923, X length 45
# Iter 924, X length 45
# Iter 925, X length 45
# Iter 926, X length 45
# Iter 927, X length 45
# Iter 928, X length 45
# Iter 929, X length 45
# Iter 930, X length 45
# Iter 931, X length 45
# Iter 932, X length 45
# Iter 933, X length 45
# Iter 934, X length 45
# Iter 935, X length 45
# Iter 936, X length 45
# Iter 937, X length 45
# Iter 938, X length 45
# Iter 939, X length 45
# Iter 940, X length 45
# Iter 941, X length 45
# Iter 942, X length 45
# Iter 943, X length 45
# Iter 944, X length 45
# Iter 945, X length 45
# Iter 946, X length 45
# Iter 947, X length 45
# Iter 948, X length 45
# Iter 949, X length 45
# Iter 950, X length 45
# Iter 951, X length 45
# Iter 952, X length 45
# Iter 953, X length 45
# Iter 954, X length 45
# Iter 955, X length 45
# Iter 956, X length 45
# Iter 957, X length 45
# Iter 958, X length 45
# Iter 959, X length 45
# Iter 960, X length 45
# Iter 961, X length 45
# Iter 962, X length 45
# Iter 963, X length 45
# Iter 964, X length 45
# Iter 965, X length 45
# Iter 966, X length 45
# Iter 967, X length 45
# Iter 968, X length 45
# Iter 969, X length 45
# Iter 970, X length 45
# Iter 971, X length 45
# Iter 972, X length 45
# Iter 973, X length 45
# Iter 974, X length 45
# Iter 975, X length 45
# Iter 976, X length 45
# Iter 977, X length 45
# Iter 978, X length 45
# Iter 979, X length 45
# Iter 980, X length 45
# Iter 981, X length 45
# Iter 982, X length 45
# Iter 983, X length 45
# Iter 984, X length 45
# Iter 985, X length 45
# Iter 986, X length 45
# Iter 987, X length 45
# Iter 988, X length 45
# Iter 989, X length 45
# Iter 990, X length 45
# Iter 991, X length 45
# Iter 992, X length 45
# Iter 993, X length 45
# Iter 994, X length 45
# Iter 995, X length 45
# Iter 996, X length 45
# Iter 997, X length 45
# Iter 998, X length 45
# Iter 999, X length 45

# %%
print(X0)
display(X0,Xorg)
# Out:
# [<Point.Point object at 0x000002712B4CC890>, <Point.Point object at 0x00000271275A3C40>, <Point.Point object at 0x0000027127585470>, <Point.Point object at 0x00000271275879A0>, <Point.Point object at 0x000002712B4C6B30>, <Point.Point object at 0x00000271275A1160>, <Point.Point object at 0x000002712756CC20>, <Point.Point object at 0x00000271275B8520>, <Point.Point object at 0x00000271275A03D0>, <Point.Point object at 0x00000271275BABA0>, <Point.Point object at 0x00000271275BBBD0>, <Point.Point object at 0x00000271275A1EF0>, <Point.Point object at 0x0000027127555010>, <Point.Point object at 0x000002712756FF50>, <Point.Point object at 0x0000027127585400>, <Point.Point object at 0x000002712B4C7540>, <Point.Point object at 0x00000271275A2AC0>, <Point.Point object at 0x0000027127557850>, <Point.Point object at 0x000002712B4C7BD0>, <Point.Point object at 0x00000271275A1C50>, <Point.Point object at 0x00000271275A32A0>, <Point.Point object at 0x0000027127557D90>, <Point.Point object at 0x00000271275A27B0>, <Point.Point object at 0x00000271275A3230>, <Point.Point object at 0x00000271275B9470>, <Point.Point object at 0x0000027127555E80>, <Point.Point object at 0x00000271275B91D0>, <Point.Point object at 0x000002712756DDA0>, <Point.Point object at 0x000002712756EE40>, <Point.Point object at 0x000002712B568A60>, <Point.Point object at 0x00000271275A2CF0>, <Point.Point object at 0x00000271275869E0>, <Point.Point object at 0x0000027127585A20>, <Point.Point object at 0x000002712B41F380>, <Point.Point object at 0x00000271275A1390>, <Point.Point object at 0x0000027127556CF0>, <Point.Point object at 0x000002712756D5C0>, <Point.Point object at 0x00000271275D4BB0>, <Point.Point object at 0x000002712756D240>, <Point.Point object at 0x00000271275D4AD0>, <Point.Point object at 0x000002712756F9A0>, <Point.Point object at 0x00000271275A2270>, <Point.Point object at 0x000002712B5695C0>, <Point.Point object at 0x00000271275544B0>, <Point.Point object at 0x000002712756DE10>]

# %%
for point in X0:
    plt.scatter(point.eval_f[0], point.eval_f[1], color='red')

plt.xlabel('X1')
plt.ylabel('X2')
plt.title('Points Visualization')
plt.legend()
plt.show()
# Out:
# C:\Users\ellie\AppData\Local\Temp\ipykernel_6784\3151587504.py:7: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()
